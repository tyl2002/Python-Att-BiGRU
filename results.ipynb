# %% [markdown]
# 不同优化器

# %%
yhat_adagrad_64=[]
output_value_adagrad_64=[0.013929,0.000300,0.017320,0.996111,21.000000]
output_value_SGD_64=[0.004891,0.000025,0.005027,0.999672,38.000000]
output_value_Adam_64=[0.108349,0.019987,0.141377,0.740849,42.000000]
output_value_Nadam_64=[0.107893,0.019364,0.139155,0.748929,39.000000]

# %%
import numpy as np
from matplotlib import pyplot as plt

y_opt_SGD=[output_value_SGD_64[0],output_value_SGD_64[2]]
y_opt_Adam=[output_value_Adam_64[0],output_value_Adam_64[2]]
y_opt_Adagrand=[output_value_adagrad_64[0],output_value_adagrad_64[2]]
y_opt_Nadam=[output_value_Nadam_64[0],output_value_Nadam_64[2]]
plt.figure(figsize=(13, 4))
labels = ['MAE','RMSE']
plt.subplot(133)
x = np.arange(len(labels))  # x轴刻度标签位置
width = 0.2  # 柱子的宽度
# 计算每个柱子在x轴上的位置，保证x轴刻度标签居中
plt.bar(x - 1.5*width, y_opt_SGD, width, label='SGD',hatch='//')
plt.bar(x - 0.5*width, y_opt_Adam, width, label='Adam',hatch='\\')
plt.bar(x + 0.5*width, y_opt_Adagrand, width, label='Adagrad',hatch='-')
plt.bar(x + 1.5*width, y_opt_Nadam, width, label='Nadam',hatch='*')
plt.ylabel('Scores')
plt.title('MAE RMSE')
# x轴刻度标签位置不进行计算
plt.xticks(x, labels=labels)
plt.legend()
plt.show()

# %%
plt.rcParams.update({'font.size': 8})
y_opt_SGD=[output_value_SGD_64[3]]
y_opt_Adam=[output_value_Adam_64[3]]
y_opt_Adagrand=[output_value_adagrad_64[3]]
y_opt_Nadam=[output_value_Nadam_64[3]]
plt.figure(figsize=(13, 4))
labels = ['R-Square']
plt.subplot(133)
x = np.arange(len(labels))  # x轴刻度标签位置
width = 0.2  # 柱子的宽度
# 计算每个柱子在x轴上的位置，保证x轴刻度标签居中
plt.bar(x - 1.5*width, y_opt_SGD, width, label='SGD',hatch='//')
plt.bar(x - 0.5*width, y_opt_Adam, width, label='Adam',hatch='\\')
plt.bar(x + 0.5*width, y_opt_Adagrand, width, label='Adagrad',hatch='-')
plt.bar(x + 1.5*width, y_opt_Nadam, width, label='Nadam',hatch='*')
plt.ylabel('Scores')
plt.title('R-Square')
# x轴刻度标签位置不进行计算
plt.xticks(x, labels=labels)
plt.legend(prop={'family':'SimHei','size':7})
plt.show()

# %%
output_value_16=[0.004992,0.000037,0.006051,0.999525,142.000000]
output_value_32=[0.004724,0.000027,0.005163,0.999654,79.000000]
output_value_64=[0.004891,0.000025,0.005027,0.999672,38.000000]
output_value_128=[0.004350,0.000020,0.004497,0.999738,19.000000]

# %%
y_opt_16=[output_value_16[0],output_value_16[2]]
y_opt_32=[output_value_32[0],output_value_32[2]]
y_opt_64=[output_value_64[0],output_value_64[2]]
y_opt_128=[output_value_128[0],output_value_128[2]]
plt.figure(figsize=(13, 4))
labels = ['MAE','RMSE']
plt.subplot(133)
x = np.arange(len(labels))  # x轴刻度标签位置
width = 0.2  # 柱子的宽度
# 计算每个柱子在x轴上的位置，保证x轴刻度标签居中
plt.bar(x - 1.5*width, y_opt_16, width, label='betch_size=16',hatch='//')
plt.bar(x - 0.5*width, y_opt_32, width, label='betch_size=32',hatch='\\')
plt.bar(x + 0.5*width, y_opt_64, width, label='betch_size=64',hatch='-')
plt.bar(x + 1.5*width, y_opt_128, width, label='betch_size=128',hatch='*')
plt.ylabel('Scores')
plt.title('MAE RMSE')
# x轴刻度标签位置不进行计算
plt.xticks(x, labels=labels)
plt.legend(prop={'family':'SimHei','size':7})
plt.show()

# %%
plt.rcParams.update({'font.size': 8})
y_opt_16=[output_value_16[3]]
y_opt_32=[output_value_32[3]]
y_opt_64=[output_value_64[3]]
y_opt_128=[output_value_128[3]]
plt.figure(figsize=(13, 4))
labels = ['R-Square']
plt.subplot(133)
x = np.arange(len(labels))  # x轴刻度标签位置
width = 0.2  # 柱子的宽度
# 计算每个柱子在x轴上的位置，保证x轴刻度标签居中
plt.bar(x - 1.5*width, y_opt_16, width, label='betch_size=16',hatch='//')
plt.bar(x - 0.5*width, y_opt_32, width, label='betch_size=32',hatch='\\')
plt.bar(x + 0.5*width, y_opt_64, width, label='betch_size=64',hatch='-')
plt.bar(x + 1.5*width, y_opt_128, width, label='betch_size=128',hatch='*')
plt.ylabel('Scores')
plt.title('R-Square')
# x轴刻度标签位置不进行计算
plt.xticks(x, labels=labels)
plt.legend(prop={'family':'SimHei','size':4},loc='upper left')
plt.show()

# %% [markdown]
# 其他数据

# %%
from code2 import y_r

yhat_industry_GRU=[0.029998,0.001360,0.036879,0.861668,39.000000]
yhat_industry=[0.002191,0.000005,0.002269,0.999476,7.000000]
yhat_GT_GRU=[0.002900,0.000020,0.004494,0.967128,37.000000]
yhat_GT=[0.002131,0.000010,0.003156,0.983788,21.000000]
# Out:
# WARNING:tensorflow:From D:\project\pythonProject2\code2.py:3: The name tf.random.set_random_seed is deprecated. Please use tf.compat.v1.random.set_random_seed instead.
#
# (1114, 12, 1)
# (1114, 1, 1)
# (471, 12, 1)
# (471, 1, 1)
# WARNING:tensorflow:From D:\tools\anconda\envs\tensorflow-gpu\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From D:\tools\anconda\envs\tensorflow-gpu\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ...

# %%
# Out:
# array([[ 0.503499],
#        [ 0.501036],
#        [ 0.50432 ],
#        [ 0.50441 ],
#        [ 0.460881],
#        [ 0.442698],
#        [ 0.550872],
#        [ 0.496811],
#        [ 0.454909],
#        [ 0.541324],
#        [ 0.512394],
#        [ 0.471567],
#        [ 0.459398],
#        [ 0.537966],
#        [ 0.498217],
#        [ 0.49415 ],
#        [ 0.506648],
#        [ 0.50202 ],
#        [ 0.46941 ],
#        [ 0.46064 ],
#        [ 0.52766 ],
#        [ 0.501441],
#        [ 0.49848 ],
#        [ 0.506836],
#        [ 0.503514],
#        [ 0.475166],
#        [ 0.445836],
#        [ 0.53928 ],
#        [ 0.506217],
#        [ 0.500024],
#        [ 0.512219],
#        [ 0.525516],
#        [ 0.49761 ],
#        [ 0.469286],
#        [ 0.482882],
#        [ 0.528118],
#        [ 0.501107],
#        [ 0.503572],
#        [ 0.515921],
#        [ 0.469272],
#        [ 0.440948],
#        [ 0.543787],
#        [ 0.500296],
#        [ 0.501748],
#        [ 0.501092],
# ...
